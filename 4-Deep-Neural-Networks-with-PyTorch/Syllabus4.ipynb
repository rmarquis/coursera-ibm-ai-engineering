# %% [markdown]
# # Deep Neural Networks with PyTorch
#
# By IBM.
#
# Welcome to Deep Neural Networks with PyTorch! You’re joining thousands of learners currently enrolled in the course. I'm excited to have you in the class and look forward to your contributions to the learning community.
#
# To begin, I recommend taking a few minutes to explore the course site. Review the material we’ll cover each week, and preview the assignments you’ll need to complete to pass the course. Click Discussions to see forums where you can discuss the course material with fellow students taking the class.
#
# If you have questions about course content, please post them in the forums to get help from others in the course community. For technical problems with the Coursera platform, visit the Learner Help Center.
#
# Good luck as you get started, and I hope you enjoy the course!

# %% [markdown]
# ## Week 1: Tensor and Datasets
#
# ### Key Concepts
#
# - Tensors 1D
# - Two-Dimensional Tensors
# - Data Set
# - Differentiation in PyTorch
#
# ### 1.0 Overview of Tensors
#
# - Overview of Tensors
#
# ### 1.1 Tensors 1D
#
# - Tensors 1D
# - Reading: Labs
# - [Ungraded External Tool: Lab Tensors 1D](1.1_1_Dtensors_v2.ipynb)
# - [Quiz: Tensors 1D](Quiz1.ipynb)
#
# ### 1.2 Two-Dimensional Tensors
#
# - Two-Dimensional Tensors
# - [Ungraded External Tool: Lab Two-Dimensional Tensors](1.1_2_Two-Dimensional_Tensors_v2.ipynb)
# - [Quiz: Two-Dimensional Tensors](Quiz1.ipynb)
#
# ### 1.3 Derivatives in PyTorch
#
# - Differentiation in PyTorch
# - [Ungraded External Tool: Lab Differentiation in PyTorch](1.2_Derivatives_and_Graphs_in_Pytorch_v2.ipynb)
# - [Quiz: Derivatives in PyTorch](Quiz1.ipynb)
#
# ### 1.4 Simple Dataset
# - Simple Dataset
# - [Ungraded External Tool: Lab Simple Data Set](1.3.1_Simple_Data_Set_v2.ipynb)
# - [Quiz: Simple Dataset](Quiz1.ipynb)
#
# ### 1.5 Dataset
#
# - Dataset
# - [Ungraded External Tool: Lab Data Set](1.3.2_Datasets_and_transforms.ipynb)
# - [Ungraded External Tool: Lab Torch Vision Datasets](1.3.3_Pre-Built_Datasets_and_transforms_v2.ipynb)
# - [Quiz: Datasets](Quiz1.ipynb)

# %% [markdown]
# ## Week 2: Linear Regression
#
# ### Key Concepts
#
# * Linear Regression Prediction
# * Linear Regression Training
# * Loss
# * Gradient Descent
# * Cost
# * Linear Regression Training PyTorch
#
# ### 2.1 Linear Regression in 1D - Prediction
# * Linear Regression Prediction
# * [Ungraded External Tool: Lab Linear Regression 1D: Prediction](2.1_Prediction_1D_regression_v3.ipynb)
# * Purchase course to unlock this item.
# * [Quiz: Prediction in One Dimension](Quiz2.ipynb)
#
# ### 2.2 Linear Regression Training
# * Linear Regression Training
# * [Quiz: Linear Regression Training](Quiz2.ipynb)
# * Loss
# * [Quiz: Loss](Quiz2.ipynb)
#
# ### 2.3 Gradient Descent and Cost
# * Gradient Descent
# * [Quiz: Gradient Descent](Quiz2.ipynb)
# * Cost
# * [Quiz: Cost](Quiz2.ipynb)
#
# ### 2.4 PyTorch Slope
# * Linear Regression PyToch
# * [Ungraded External Tool: Lab Linear Regression 1D: Prediction](2.2_Linear_regression_one_parameter_v3.ipynb)
# * [Quiz: Training Parameters in PyTorch](Quiz2.ipynb)
#
# ### 2.5 Linear Regression Training
# * PyTorch Linear Regression Training Slope and Bias
# * [Ungraded External Tool: Lab Linear Regression: Prediction](2.3_Training_slope_and_bias_v3.ipynb)
# * [Quiz: PyTorch Linear Regression Training Slope and Bias](Quiz2.ipynb)

# %% [markdown]
# ## Week 2: Linear Regression PyTorch Way

# %% [markdown]
# ### Key Concepts
# * Data Loader
# * Mini-Batch Gradient Descent
# * Stochastic Gradient Descent
# * Training, Validation and Test Split
# * Optimization in PyTorch
#
# ### 3.1 Stochastic Gradient Descent and the Data Loader
# * Stochastic Gradient Descentaddsub
# * [Ungraded External Tool: Lab Linear Regression 1D: Prediction Stochastic Gradient Descent and the Data Loader](3.1_Stochastic_gradient_descent_v3.ipynb)
# * [Quiz: Stochastic Gradient Descent](Quiz2.ipynb)
#
# ### 3.2 Mini-Batch Gradient Descent
# * Mini-Batch Gradient Descent
# * [Ungraded External Tool: Mini-Batch Gradient Descent](3.2_Mini-batch_gradient_descent_v3.ipynb)
# * [Quiz: Mini-Batch Gradient Descent](Quiz2.ipynb)
#
# ### 3.3 Optimization in PyTorch
# * Optimization in PyTorch
# * [Ungraded External Tool: Linear Regression 1D PyTorch](3.3_PyTorchway_v3.ipynb)
# * [Quiz: Optimization in PyTorch](Quiz2.ipynb)
#
# ### 3.4 Training, Validation and Test Split
# * Training, Validation and Test Split
# * Training, Validation and Test Split PyTorch
# * [Ungraded External Tool: Training, Validation and Test Split in PyTorch](3.6_Training_and_validation_v3.ipynb)
# * [Quiz: Training and Validation Data PyTorch](Quiz2.ipynb)

# %% [markdown]
# ## Week 3: Multiple Input Output Linear Regression
#
# ## Key Concepts
# * Multiple Linear Regression
# * Multiple Linear Regression Training
# * Linear Regression Multiple Outputs
# * Linear Regression Multiple Outputs Training
#
# ## 4.1 Multiple Linear Regression Prediction
# * Multiple Linear Regression Prediction
# * [Ungraded External Tool: Multiple Linear Regression Prediction](4.1_Multiple_linear_regression_prediction_v2.ipynb)
# * Multiple Linear Regression Training
# * [Ungraded External Tool: Multiple Linear Regression Training](4.2_Multiple_linear_regression_training_v2.ipynb)
# * [Quiz: Multiple Linear Regression Prediction](Quiz3.ipynb)
#
# ## 4.2 Multiple Output Linear Regression
#
# * Linear Regression Multiple Outputs
# * [Ungraded External Tool: Multiple Linear Regression Prediction](4.3_Multi-target_linear_regression.ipynb)
# * Multiple Output Linear Regression Training
# * [Ungraded External Tool: Multiple Linear Regression Training](4.4_Training_multiple_output_linear_regression.ipynb)
# * [Quiz: Multiple Output Linear Regression](Quiz3.ipynb)
#
# ## Week 3: Logistic Regression for Classification
#
# ## Key Concepts
#
# * Linear Classifiers
# * Logistic Regression: Prediction
# * Bernoulli Distribution and Maximum Likelihood Estimation
# * Cross Entropy Loss
#
# ### 5.0 Linear Classier and Logistic Regression
# * Linear Classifiers
# * [Quiz: Linear Classifiers](Quiz3.ipynb)
# * [Quiz: Linear Classifiers](Quiz3.ipynb)
#
# ### 5.1 Logistic Regression Prediction
# * Logistic Regression: Prediction
# * [Ungraded External Tool: Logistic Regression Prediction](5.1_Logistic_regression_prediction_v2.ipynb)
# * [Quiz: Logistic Regression: Prediction](Quiz3.ipynb)
#
# ### 5.2 Bernoulli Distribution Maximum Likelihood Estimation
# * Bernoulli Distribution and Maximum Likelihood Estimation
# * [Quiz: Bernoulli Distribution and Maximum Likelihood Estimation](Quiz3.ipynb)
#
# ### 5.3 Logistic RegressionCross Entropy Loss
# * Logistic Regression Cross Entropy Loss
# * [Ungraded External Tool: Logistic Regression Mean Square Error](5.2.2_Bad_initialization_logistic_regression_with_mean_square_error_v2.ipynb)
# * [Ungraded External Tool: Logistic Regression Cross Entropy](5.3_Cross_entropy_logistic_regression_v2.ipynb)
# * [Quiz: Logistic Regression Cross Entropy Loss](Quiz3.ipynb)

# %% [markdown]
# ## Week 4: Softmax Regression
#
# ### Key Concepts
#
# * Using Lines to Classify Data
# * Softmax Prediction in PyTorch
# * Softmax Pytorch MNIST
#
# ### 6.1 Softmax Prediction
# * Softmax
# * [Quiz: Softmax Function:Using Lines to Classify Data](Quiz4.ipynb)
#
# ### 6.2 Softmax Function
# * Softmax Function: Using Lines to Classify Data
# * [Quiz: Softmax Prediction](Quiz4.ipynb)
#
# ### 6.3 Softmax PyTorch
# * Softmax PyTorch
# * [Ungraded External Tool: Softmax Classier 1](5.4_Softmax_in_one_dimension_v2.ipynb)
# * [Ungraded External Tool: Softmax Classier 2](6.2_Lab_predicting_MNIST_using_Softmax_v2.ipynb)
# * [Quiz: Softmax PyTorch Quizz](Quiz4.ipynb)
#
# ## Week 4: Shallow Neural Networks
#
# ### Key Concepts
#
# * Simple Neural Networks
# * More Hidden Neurons
# * Neural Networks with Multiple Dimensional
# * Multi-Class Neural Networks
# * Backpropagation
# * Activation Functions
#
# ### 7.1 Neural Networks in One Dimension
# * What's a Neural Network
# * [Ungraded External Tool: Neural Networks in One Dimension](7.1_Simple_1_hidden_layer.ipynb)
# * [Quiz: Neural Networks](Quiz4.ipynb)
#
# ### 7.2 Neural Networks More Hidden Neurons
# * More Hidden Neurons
# * [Ungraded External Tool: More Hidden Neurons](7.2_Multiple_neurons.ipynb)
# * [Quiz: More Hidden Neurons](Quiz4.ipynb)
#
# ### 7.3 Neural Networks with Multiple Dimensional Input
# * Neural Networks with Multiple Dimensional Input
# * [Ungraded External Tool: Multidimensional Neural Network](7.3_xor_v2.ipynb)
# * [Quiz: Neural Networks with Multiple Dimensional Inputs](Quiz4.ipynb)
#
# ### 7.4 Multi-Class Neural Networks
# * Multi-Class Neural Networks
# * [Ungraded External Tool:Multi-Class Neural Networks with MNIST](7.4_One_layer_neural_network_MNIST.ipynb)
# * [Quiz: Multi-Class Neural Networks](Quiz4.ipynb)
#
# ### 7.5 Backpropagation
# * Backpropagation
# * [Quiz: Backpropagation](Quiz4.ipynb)
#
# ### 7.6 Activation Functions
# * Activation Functions
# * [Ungraded External Tool: Activation Functions](7.5.1_Activation_function_v2.ipynb)
# * [Ungraded External Tool: Neural Network with Different Activation Functions](7.5.2_Mist_1_layer_v2.ipynb)
# * [Quiz: Activation Functions](Quiz4.ipynb)

# %% [markdown]
# ## Week 5: Deep Neural Networks
#
# ### Key Concepts
#
# * Building deep networks
# * Dropout
# * Neural Network initialization weights
# * Gradient Descent with Momentum
#
# ### 8.1 Deep Neural Networks
# * Deep Neural Networks
# * [Ungraded External Tool: Deep Neural Networks](8.1.1_Mist_2_layer_v2.ipynb)
# * [Quiz: Deep Neural Networks](Quiz5.ipynb)
# * Deeper Neural Networks : nn.ModuleList()
# * [Ungraded External Tool: Deeper Neural Networks : nn.ModuleList()](8.1.2_Mulitclass_spiralrulu_v2.ipynb)
# * [Quiz: Deeper Neural Networks : nn.ModuleList()](Quiz5.ipynb)
#
# ### 8.2 Dropout
# * Dropout
# * [Ungraded External Tool: Dropout Classification](8.2.1_Dropout_Prediction_v2.ipynb)
# * [Ungraded External Tool: Dropout regression](8.2.2_Dropout_Regression_v2.ipynb)
# * [Quiz: Dropout](Quiz5.ipynb)
#
# ### 8.3 Neural Network initialization weights
# * Neural Network initialization Weights
# * [Ungraded External Tool: Initialization](8.3.1_Initialization_same.ipynb)
# * [Ungraded External Tool: Initialization Xavier](8.3.2_Xavier_mist_1_layer_v2.ipynb)
# * [Ungraded External Tool: Initialization He](8.3.3_He_Initialization_v2.ipynb)
# * [Quiz: Neural Network initialization](Quiz5.ipynb)
#
# ### 8.4 Gradient Descent with Momentum
# * Gradient Descent with Momentum
# * [Ungraded External Tool: Momentum with Different Polynomials](8.4.1_Momentum_with_Polynomial_Functions_v2.ipynb)
# * [Ungraded External Tool: Neural network momentum](8.4.2_Neural_Networks_with_Momentum_v2.ipynb)
# * [Quiz: Gradient Descent with Momentum](Quiz5.ipynb)
#
# ### 8.5 Batch Normalization
# * Batch Normalization
# * [Ungraded External Tool: Batch Normalization](8.5.1_Bach_Norm_v2.ipynb)
# * [Quiz: Batch Normalization](Quiz5.ipynb)

# %% [markdown]
# ## Week 6: Convolutional Neural Network
#
# ### Key Concepts
# * Convolution
# * Activation Functions
# * Max Pooling
# * Convolution: Multiple Channels
# * Convolutional Neural Network
# * TORCH-VISION MODELS
#
# ### 9.1 Convolution
# * Convolution
# * [Ungraded External Tool: Lab What's Convolution](9.1_What_is_Convolution.ipynb)
# * [Quiz: Convolution](Quiz6.ipynb)
#
# ### 9.2 Activation Functions and Max Polling
# * Activation Functions and Max Polling
# * [Ungraded External Tool: Lab Activation function and Maxpooling](9.2_Activation_max_pooling.ipynb)
# * [Quiz: Activation Functions and Max Pooling](Quiz6.ipynb)
#
# ### 9.3 Multiple Input and Output Channels
# * Multiple Input and Output Channels
# * [Ungraded External Tool: Multiple Input and Output Channels](9.3_Multiple_Channel_Convolution.ipynb)
# * [Quiz: Convolutional Neural Network](Quiz6.ipynb)
#
# ### 9.4 Convolutional Neural Network
# * Convolutional Neural Network
# * Convolutional Neural Network
# * [Ungraded External Tool: Convolutional Neural Network Simple example](9.4.1_Convolutional_Neural_Network_Simple_example.ipynb)
# * [Ungraded External Tool: Convolutional Neural Network MNIST](9.4.2_CNN_Small_Image.ipynb)
# * [Ungraded External Tool: Convolutional Neural Networks with Batch Norm (Honors only)](9.4.3_CNN_Small_Image_batch.ipynb)
# * [Quiz: Convolutional Neural Networks](Quiz6.ipynb)
#
# ### 9.5 TORCH-VISION MODELS
# * TORCH-VISION MODELS
# * [Quiz: TORCH-VISION MODELS](Quiz6.ipynb)

# %% [markdown]
# ## Week 7: Peer Review
#
# ### Key Concepts
# * Apply all you have learned to train a Convolutional Neural Network
#
# ### Fashion MNIST Classification Assignment
# * Honors: Setup
# * [Honors Peer-graded Assignment: Fashion MNIST Classification Assignment](Honors_Peer-graded_Assignment_Fashion_MNIST_Class.ipynb)
# * Review Your Peers: Fashion MNIST Classification Assignment
